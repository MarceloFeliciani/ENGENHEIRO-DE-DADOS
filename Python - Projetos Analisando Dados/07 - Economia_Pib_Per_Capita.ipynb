# %% [markdown]
# Projeto inspirado pelo prof Odemir Jr
#
# Conjunto de dados Economicos do Brasil
# Dados da renda per capita dos estados da união
#
# link oficial dos dados: http://www.atlasbrasil.org.br/
#
# O que é Renda Per Capita?
#
# A renda per capita é um dos indicadores socioeconômicos que avaliam o grau de desenvolvimento econômico de um determinado lugar. A média é obtida através da divisão do Produto Nacional Bruto (PNB) pelo número total de habitantes.

# %%
# Bibliotecas necessarias
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Base de dados
Base_Dados = pd.read_excel('/content/drive/MyDrive/Projetos_OdemirJr/Projeto07 -  Projeto Economia - Pib Per Capita/Dados_Pib.xlsx')

# Verificando dados importados
Base_Dados.head(10)
# Out:
#   Territorialidades   Ano  PIB per capita
# 0            Brasil  2013           22.20
# 1              Acre  2013           12.37
# 2           Alagoas  2013            9.45
# 3             Amapá  2013           14.53
# 4          Amazonas  2013           18.25
# 5             Bahia  2013           11.40
# 6             Ceará  2013           10.40
# 7  Distrito Federal  2013           52.77
# 8    Espírito Santo  2013           25.56
# 9             Goiás  2013           19.68

# %%
# Media do PIB Per capta das regioes por ano
Base_Dados.groupby( by=['Territorialidades', 'Ano'] ).mean().head(30)
# Out:
#                         PIB per capita
# Territorialidades Ano
# Acre              2013           12.37
#                   2014           13.41
#                   2015           12.24
#                   2016           11.18
# Alagoas           2013            9.45
#                   2014            9.71
#                   2015           10.02
#                   2016            9.78
# Amapá             2013           14.53
#                   2014           14.05
#                   2015           13.05
#                   2016           12.17
# Amazonas          2013           18.25
#                   2014           17.61
#                   2015           15.87
#                   2016           14.77
# Bahia             2013           11.40
#                   2014           11.65
#                   2015           11.64
#                   2016           11.24
# Brasil            2013           22.20
#                   2014           22.44
#                   2015           21.17
#                   2016           20.19
# Ceará             2013           10.40
#                   2014           11.22
#                   2015           10.59
#                   2016           10.25
# Distrito Federal  2013           52.77
#                   2014           54.48

# %%
# Sistema de Grids

# Cor Fundo de Fundo
Cor_Fundo = '#f5f5f5'

# Criar o sistema de Grids
Grid_Graficos = sns.FacetGrid( Base_Dados, col='Territorialidades', hue='Territorialidades', col_wrap=4 )

# Adicionar grafico linhas em cada gráfico
Grid_Graficos = Grid_Graficos.map( plt.plot, 'Ano', 'PIB per capita')

# Adiconar uma sombra + Ajuste do titulo
Grid_Graficos = Grid_Graficos.map( plt.fill_between,  'Ano', 'PIB per capita', alpha=0.2).set_titles('{col_name} Territorialidades')

# Filtrar o titulo
Grid_Graficos = Grid_Graficos.set_titles('{col_name}')

# Adicionar um subtitulo
Grid_Graficos = Grid_Graficos.fig.suptitle(
    'Evolução da Renda per capita por Estado \n Esse relatório foi elaborado no treinado "Python para Análise de Dados" \n Está dispónivel no canal do youtube @Data Viking',
    fontsize=18
)

# Ajustando
plt.subplots_adjust( top=0.92 )
